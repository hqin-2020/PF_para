# %%
import numpy as np
import scipy as sp
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import time
from tqdm import tqdm
import pickle
import os
import multiprocessing

from PF_Aso1_0 import *

workdir = os.path.dirname(os.path.dirname(os.getcwd()))
srcdir = os.getcwd()
outputdir = workdir + '/output/Aso1_0/'

# %%
seed = 7
T = 300
N = 10000
Λ_scale = 1
cd_scale = 1
true_θ = {'Azo' : np.zeros((2,1)),\
          'Azz' : np.array([[1, 1], [0, 0.5]]),\
          'Aso' : np.array([[0.],[8.],[6.]]),\
          'Bz'  : np.array([[1., 0],[0, .5]]),\
          'Ass' : np.array([[0.6, 0.1, 0.1],\
                            [0.2, 0.5, 0.3],\
                            [0.1, 0.2, 0.4]]),\
          'Bs'  : np.array([[3,   0,   0],\
                            [0.5, 2,   0],\
                            [0.3, 0.2, 1]])}
obs_series = simulate(true_θ, T)

# %%
D_0 = obs_series[:,[0]]
θXHν_0 = []
for i in range(N):
    θXHν_0.append(init(true_θ, D_0, Λ_scale, cd_scale))
    
particle_series = [θXHν_0]
particle_TEMP_series = [θXHν_0]
w_series = [np.ones(N)/N]
count_series = [np.ones(N)]

for t in tqdm(range(T-1)):
    
    D_t_next = obs_series[:,[t+1]]
    input_t = [[particle_series[-1][i][1], particle_series[-1][i][2], D_t_next, seed+t+i] for i in range(N)]
        
    if __name__ == '__main__':
        pool = multiprocessing.Pool()
        output_t = pool.map(update_θXHν, input_t)      
    particle_TEMP_series.append(output_t)
    
    ν_t = [i[3] for i in output_t]
    w_t_next = ν_t/np.sum(ν_t)
    try:
        count_all = sp.stats.multinomial.rvs(N, w_t_next)
    except:
        for i in range(N):
            if w_t_next[i]>(np.sum(w_t_next[:-1]) - 1):
                w_t_next[i] = w_t_next[i] - (np.sum(w_t_next[:-1]) - 1)
                break
        count_all = sp.stats.multinomial.rvs(N, w_t_next)
    count_series.append(count_all)
    w_series.append(w_t_next)
    particle_t_next = []
    for i in range(N):
        if count_all[i] != 0:
            for n in range(count_all[i]):
                particle_t_next.append(output_t[i])    
    particle_series.append(particle_t_next)
# Out:
#   1%|█                                                                                                                                                                    | 2/299 [00:23<58:11, 11.76s/it]Process SpawnPoolWorker-24:
# Process SpawnPoolWorker-22:
# Process SpawnPoolWorker-18:
# Process SpawnPoolWorker-19:
# Process SpawnPoolWorker-20:
#   1%|█                                                                                                                                                                  | 2/299 [00:31<1:16:46, 15.51s/it]Process SpawnPoolWorker-23:
# Process SpawnPoolWorker-17:
# Process SpawnPoolWorker-21:
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 265, in update_θXHν
#     θti_next = update_θ(Hti)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 91, in update_θ
#     β_s3, σ2_s3 = draw_para(H['5th'][0], H['5th'][1], H['5th'][2], H['5th'][3])
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 57, in draw_para
#     β = np.random.multivariate_normal(b.flatten(), sp.linalg.inv(ζ*Λ)).reshape(-1,1)
#   File "mtrand.pyx", line 4127, in numpy.random.mtrand.RandomState.multivariate_normal
#   File "<__array_function__ internals>", line 5, in allclose
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py", line 2249, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "<__array_function__ internals>", line 5, in isclose
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py", line 2352, in isclose
#     dt = multiarray.result_type(y, 1.)
#   File "<__array_function__ internals>", line 5, in result_type
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 265, in update_θXHν
#     θti_next = update_θ(Hti)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 90, in update_θ
#     β_s2, σ2_s2 = draw_para(H['4th'][0], H['4th'][1], H['4th'][2], H['4th'][3])
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Versio
# n, PF collection/src/Aso1_0/PF_Aso1_0.py", line 55, in draw_para
#     ζ = sp.stats.gamma.rvs(c/2+1, loc = 0, scale = 1/(d/2))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 1064, in rvs
#     args, loc, scale, size = self._parse_args_rvs(*args, **kwds)
#   File "<string>", line 6, in _parse_args_rvs
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 895, in _argcheck_rvs
#     all_bcast = np.broadcast_arrays(*args)
#   File "<__array_function__ internals>", line 5, in broadcast_arrays
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py", line 544, in broadcast_arrays
#     return [_broadcast_to(array, shape, subok=subok, readonly=False)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py", line 544, in <listcomp>
#     return [_broadcast_to(array, shape, subok=subok, readonly=False)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py", line 348, in _broadcast_to
#     it = np.nditer(
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 265, in update_θXHν
#     θti_next = update_θ(Hti)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 64, in update_θ
#     β_z1, σ2_z1 = draw_para(H['1st'][0], H['1st'][1], H['1st'][2], H['1st'][3])
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 267, in update_θXHν
#     Hti_next = update_H(Xti_next, Xti, Hti)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 55, in draw_para
#     ζ = sp.stats.gamma.rvs(c/2+1, loc = 0, scale = 1/(d/2))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 1064, in rvs
#     args, loc, scale, size = self._parse_args_rvs(*args, **kwds)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 227, in update_H
#     bayes_para_update(Ht['2nd'][0], Ht['2nd'][1], Ht['2nd'][2], Ht['2nd'][3], np.array([[1],[Zt2]]), Zt_next_2)
#   File "<string>", line 6, in _parse_args_rvs
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 895, in _argcheck_rvs
#     all_bcast = np.broadcast_arrays(*args)
#   File "<__array_function__ internals>", line 5, in broadcast_arrays
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 210, in bayes_para_update
#     dt_next = Zt_next**2 - bt_next.T@Λt_next@bt_next + bt.T@Λt@bt + dt
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py", line 544, in broadcast_arrays
#     return [_broadcast_to(array, shape, subok=subok, readonly=False)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py", line 544, in <listcomp>
#     return [_broadcast_to(array, shape, subok=subok, readonly=False)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py", line 348, in _broadcast_to
#     it = np.nditer(
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 265, in update_θXHν
#     θti_next = update_θ(Hti)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 90, in update_θ
#     β_s2, σ2_s2 = draw_para(H['4th'][0], H['4th'][1], H['4th'][2], H['4th'][3])
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 55, in draw_para
#     ζ = sp.stats.gamma.rvs(c/2+1, loc = 0, scale = 1/(d/2))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 1064, in rvs
#     args, loc, scale, size = self._parse_args_rvs(*args, **kwds)
#   File "<string>", line 6, in _parse_args_rvs
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 895, in _argcheck_rvs
#     all_bcast = np.broadcast_arrays(*args)
#   File "<__array_function__ internals>", line 5, in broadcast_arrays
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py", line 538, in broadcast_arrays
#     shape = _broadcast_shape(*args)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/lib/stride_tricks.py", line 420, in _broadcast_shape
#     b = np.broadcast(*args[:32])
# Traceback (most recent call last):
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 265, in update_θXHν
#     θti_next = update_θ(Hti)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 91, in update_θ
#     β_s3, σ2_s3 = draw_para(H['5th'][0], H['5th'][1], H['5th'][2], H['5th'][3])
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 55, in draw_para
#     ζ = sp.stats.gamma.rvs(c/2+1, loc = 0, scale = 1/(d/2))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 1069, in rvs
#     if np.all(scale == 0):
#   File "<__array_function__ internals>", line 5, in all
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 2450, in all
#     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 84, in _wrapreduction
#     return reduction(axis=axis, out=out, **passkwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py", line 63, in _all
#     return umr_all(a, axis, dtype, out, keepdims)
# KeyboardInterrupt
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 265, in update_θXHν
#     θti_next = update_θ(Hti)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 91, in update_θ
#     β_s3, σ2_s3 = draw_para(H['5th'][0], H['5th'][1], H['5th'][2], H['5th'][3])
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 57, in draw_para
#     β = np.random.multivariate_normal(b.flatten(), sp.linalg.inv(ζ*Λ)).reshape(-1,1)
#   File "mtrand.pyx", line 4127, in numpy.random.mtrand.RandomState.multivariate_normal
#   File "<__array_function__ internals>", line 5, in allclose
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py", line 2249, in allclose
#     res = all(isclose(a, b, rtol=rtol, atol=atol, equal_nan=equal_nan))
#   File "<__array_function__ internals>", line 5, in isclose
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/numeric.py", line 2357, in isclose
#     if all(xfin) and all(yfin):
#   File "<__array_function__ internals>", line 5, in all
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 2450, in all
#     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 73, in _wrapreduction
#     if type(obj) is not mu.ndarray:
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 265, in update_θXHν
#     θti_next = update_θ(Hti)
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 91, in update_θ
#     β_s3, σ2_s3 = draw_para(H['5th'][0], H['5th'][1], H['5th'][2], H['5th'][3])
#   File "/Users/haominqin/Dropbox/Mac/Documents/Estimation Projects/36th Version, PF collection/src/Aso1_0/PF_Aso1_0.py", line 55, in draw_para
#     ζ = sp.stats.gamma.rvs(c/2+1, loc = 0, scale = 1/(d/2))
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/scipy/stats/_distn_infrastructure.py", line 1069, in rvs
#     if np.all(scale == 0):
#   File "<__array_function__ internals>", line 5, in all
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 2450, in all
#     return _wrapreduction(a, np.logical_and, 'all', axis, None, out,
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py", line 84, in _wrapreduction
#     return reduction(axis=axis, out=out, **passkwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py", line 63, in _all
#     return umr_all(a, axis, dtype, out, keepdims)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [5], in <cell line: 11>()
#      16 if __name__ == '__main__':
#      17     pool = multiprocessing.Pool()
# ---> 18     output_t = pool.map(update_θXHν, input_t)
#      19 particle_TEMP_series.append(output_t)
#      21 ν_t = [i[3] for i in output_t]
#
# File ~/opt/anaconda3/lib/python3.9/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/opt/anaconda3/lib/python3.9/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/opt/anaconda3/lib/python3.9/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/opt/anaconda3/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     572 signaled = self._flag
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File ~/opt/anaconda3/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     310 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311     if timeout is None:
# --> 312         waiter.acquire()
#     313         gotit = True
#     314     else:
#
# KeyboardInterrupt:

# %%
try: 
    os.mkdir(outputdir + 'seed = ' + str(seed) + ', T = ' + str(T) + ', N = ' + str(N))
    casedir = outputdir + 'seed = ' + str(seed) + ', T = ' + str(T) + ', N = ' + str(N) 
except:
    casedir = outputdir + 'seed = ' + str(seed) + ', T = ' + str(T) + ', N = ' + str(N)

for t in tqdm(range(T)):
    with open(casedir + '/particle_TEMP_series_'+str(t)+'.pkl', 'wb') as f:
           pickle.dump(particle_TEMP_series[t], f)
    with open(casedir + '/count_series_'+str(t)+'.pkl', 'wb') as f:
           pickle.dump(count_series[t], f)
    with open(casedir + '/particle_series_'+str(t)+'.pkl', 'wb') as f:
           pickle.dump(particle_series[t], f)
    with open(casedir + '/w_series_'+str(t)+'.pkl', 'wb') as f:
           pickle.dump(w_series[t], f)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 300/300 [37:18<00:00,  7.46s/it]
# Process SpawnPoolWorker-2389:
# Process SpawnPoolWorker-2387:
# Process SpawnPoolWorker-2391:
# Process SpawnPoolWorker-2385:
# Process SpawnPoolWorker-2388:
# Process SpawnPoolWorker-2390:
# Process SpawnPoolWorker-2386:
# Process SpawnPoolWorker-2392:
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 366, in get
#     res = self._reader.recv_bytes()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/connection.py", line 221, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/connection.py", line 419, in _recv_bytes
#     buf = self._recv(4)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/connection.py", line 384, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 315, in _bootstrap
#     self.run()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/queues.py", line 365, in get
#     with self._rlock:
#   File "/Users/haominqin/opt/anaconda3/lib/python3.9/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
